# %%
import pandas as pd

# %%
# Load raw census data 
df = pd.read_csv('../data/census.csv')

df.head(5)
print(df.shape)
# Out:
# (32561, 15)

# %%
df.describe()
# Out:
#                 age         fnlgt   education-num   capital-gain  \
# count  32561.000000  3.256100e+04    32561.000000   32561.000000
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32561.000000     32561.000000
# mean       87.303830        40.437456
# std       402.960219        12.347429
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %%
# missing value check
df.isnull().sum()
# Out:
# age                0
#  workclass         0
#  fnlgt             0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      0
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
#  salary            0
# dtype: int64

# %%
# See more info on filling of values of the object columns
# Iterate over each object column in the DataFrame
for column in df.select_dtypes(include='object'):
    # Print column name and its unique values
    print("Column:", column)
    print(df[column].value_counts())
    print()
# Out:
# Column:  workclass
#  workclass
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: count, dtype: int64
#
# Column:  education
#  education
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: count, dtype: int64
#
# Column:  marital-status
#  marital-status
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
# ...

# %%
# Strip leading/trailing whitespaces from object column names and values
def clean_dataframe(df: pd.DataFrame) -> pd.DataFrame:
    """
    Cleans a pandas dataframe by removing leading/trailing whitespaces from object columns and their values.

    Args:
        df (pd.DataFrame): The dataframe to be cleaned.

    Returns:
        pd.DataFrame: The cleaned dataframe.
    """
       
    # Remove leading/trailing whitespaces from column names
    df.columns = [c.strip() for c in df.columns]
        
    # Remove leading/trailing whitespaces from column values
    for column in df.select_dtypes(include='object').columns:
        df[column] = df[column].str.strip()

    return df

# %%
# clean the dataset
df_clean = clean_dataframe(df)

# %%
filename = '../data/census_clean.csv'

df_clean.to_csv(filename, index=False)
